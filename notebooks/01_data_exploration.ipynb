# %%
# Cell 1: Import libraries and check location
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os
warnings.filterwarnings('ignore')

# Check current location
print("Current directory:", os.getcwd())
print("\nProject structure check:")
print("✓ notebooks/ exists:", os.path.exists('../notebooks'))
print("✓ data/ exists:", os.path.exists('../data'))
print("✓ images/ exists:", os.path.exists('../images'))

# Create images folder if it doesn't exist
os.makedirs('../images', exist_ok=True)

# Set display options
pd.set_option('display.max_columns', None)
print("\n✓ Libraries imported successfully!")
# Out:
# Current directory: C:\Users\ASUS\fraud-detection-mobile-money\notebooks
#
# Project structure check:
# ✓ notebooks/ exists: True
# ✓ data/ exists: True
# ✓ images/ exists: True
#
# ✓ Libraries imported successfully!

# %%
# Cell 2: Load data
df = pd.read_csv('../data/paysim_data.csv')
print(f"✓ Dataset loaded successfully!")
print(f"Shape: {df.shape[0]:,} rows, {df.shape[1]} columns")
print("\nFirst 5 rows:")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Cell 2: Load data
# ----> 2 df = pd.read_csv('../data/paysim_data.csv')
#       3 print(f"✓ Dataset loaded successfully!")
#       4 print(f"Shape: {df.shape[0]:,} rows, {df.shape[1]} columns")
#
# ...

# %%
# Cell 2: Load data
df = pd.read_csv('../data/paysim_data.csv')
print(f"✓ Dataset loaded successfully!")
print(f"Shape: {df.shape[0]:,} rows, {df.shape[1]} columns")
print("\nFirst 5 rows:")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Cell 2: Load data
# ----> 2 df = pd.read_csv('../data/paysim_data.csv')
#       3 print(f"✓ Dataset loaded successfully!")
#       4 print(f"Shape: {df.shape[0]:,} rows, {df.shape[1]} columns")
#
# ...

# %%
# Cell 3: Save to proper location
import shutil
shutil.copy('synthetic_fraud_dataset.csv', 'fraud-detection-mobile-money/data/paysim_data.csv')
print("✓ Data copied to project folder")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Cell 3: Save to proper location
#       2 import shutil
# ----> 3 shutil.copy('synthetic_fraud_dataset.csv', 'fraud-detection-mobile-money/data/paysim_data.csv')
#       4 print("✓ Data copied to project folder")
#
# File C:\ProgramData\anaconda3\Lib\shutil.py:428, in copy(src, dst, follow_symlinks)
#     426 if os.path.isdir(dst):
#     427     dst = os.path.join(dst, os.path.basename(src))
# --> 428 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     429 copymode(src, dst, follow_symlinks=follow_symlinks)
#     430 return dst
#
# File C:\ProgramData\anaconda3\Lib\shutil.py:260, in copyfile(src, dst, follow_symlinks)
#     258     os.symlink(os.readlink(src), dst)
#     259 else:
# --> 260     with open(src, 'rb') as fsrc:
#     261         try:
# ...

# %%
plt.savefig('fraud-detection-mobile-money/images/fraud_distribution.png', dpi=300, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plt.savefig('fraud-detection-mobile-money/images/fraud_distribution.png', dpi=300, bbox_inches='tight')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1243, in savefig(*args, **kwargs)
#    1240 fig = gcf()
#    1241 # savefig default implementation has no return, so mypy is unhappy
#    1242 # presumably this is here because subclasses can return?
# -> 1243 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1244 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1245 return res
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# ...
